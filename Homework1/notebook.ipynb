# %%
import pandas as pd
pd.__version__
# Out:
# '3.0.6'

# %%
df=pd.read_csv('C:\\projects\\ml-zoomcamp-2026\\Homework1\\car_fuel_efficiency_2026.csv')
len(df)
# Out:
# 10000

# %%
df['fuel_type'].value_counts()
# Out:
# fuel_type
# Gasoline    6913
# Diesel      2053
# Hybrid      1034
# Name: count, dtype: int64

# %%
df['fuel_type'].nunique()
# Out:
# 3

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df[df['origin'] == 'Asia']['fuel_efficiency_mpg'].max()
# Out:
# np.float64(41.2)

# %%
df['horsepower'].median()
# Out:
# np.float64(254.0)

# %%
frequent=df['horsepower'].value_counts().head(1)
frequent
# Out:
# horsepower
# 252.0    174
# Name: count, dtype: int64

# %%
df['horsepower'] = df['horsepower'].fillna(frequent.index[0])

# %%
df['horsepower'].median()
# Out:
# np.float64(252.0)

# %%
df=df[df['origin']=='Asia']
df
# Out:
#       model_year origin fuel_type         drivetrain  num_doors  \
# 2           1996   Asia  Gasoline  Front-wheel drive          5
# 6           1992   Asia  Gasoline  Front-wheel drive          2
# 8           1997   Asia  Gasoline   Rear-wheel drive          3
# 10          1978   Asia  Gasoline    All-wheel drive          3
# 15          2007   Asia    Diesel  Front-wheel drive          4
# ...          ...    ...       ...                ...        ...
# 9984        2011   Asia  Gasoline  Front-wheel drive          3
# 9987        2004   Asia    Diesel    All-wheel drive          3
# 9990        1975   Asia    Diesel  Front-wheel drive          4
# 9994        1993   Asia  Gasoline   Rear-wheel drive          2
# 9996        1993   Asia  Gasoline    All-wheel drive          2
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 2                    2320              6       267.0            4240
# ...

# %%
df=df[['vehicle_weight','model_year']]
df
# Out:
#       vehicle_weight  model_year
# 2               4240        1996
# 6               4310        1992
# 8               4230        1997
# 10              4420        1978
# 15              3950        2007
# ...              ...         ...
# 9984            4610        2011
# 9987            4530        2004
# 9990            3630        1975
# 9994            4610        1993
# 9996            4370        1993
#
# [2994 rows x 2 columns]

# %%
df=df[:7]
df
# Out:
#     vehicle_weight  model_year
# 2             4240        1996
# 6             4310        1992
# 8             4230        1997
# 10            4420        1978
# 15            3950        2007
# 16            4750        2021
# 22            4450        2019

# %%
X=df.to_numpy()
X
# Out:
# array([[4240, 1996],
#        [4310, 1992],
#        [4230, 1997],
#        [4420, 1978],
#        [3950, 2007],
#        [4750, 2021],
#        [4450, 2019]])

# %%
XTX=X.T.dot(X)
XTX
# Out:
# array([[131950500,  60750580],
#        [ 60750580,  28041424]])

# %%
import numpy as np
XTX_inv=np.linalg.inv(XTX)
XTX_inv
# Out:
# array([[ 2.96830537e-06, -6.43071025e-06],
#        [-6.43071025e-06,  1.39675281e-05]])

# %%
y=np.array([1100,1300,800,900,1000,1100,1200])
y
# Out:
# array([1100, 1300,  800,  900, 1000, 1100, 1200])

# %%
w=XTX_inv.dot(X.T).dot(y)
w
# Out:
# array([0.13644777, 0.2327492 ])

# %%
w.sum()
# Out:
# np.float64(0.36919696904925486)
